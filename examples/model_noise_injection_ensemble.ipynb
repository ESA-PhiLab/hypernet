# %% [markdown]
# # Noise injection into models, ensemble
#
# Inject noise into the model's weights to create an augmented version. There are two reasons such operation could be useful:
# - Inject noise into the model to verify its robustness agaist unpredicted noise.
# - Model could be augmented N times, forming an ensemble. Each model makes its own predictions, which are then aggregated to conclude a final prediction.

# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
import os

import tensorflow as tf

from scripts import evaluate_model, prepare_data, artifacts_reporter, train_model

# %% [markdown]
# Specify path to the `.npy` dataset and ground truth, as well as the output path to store all the artifacts.

# %%
DEST_PATH = 'example_results'
DATA_FILE_PATH = os.path.join(os.path.dirname(os.getcwd()), 'datasets/pavia/pavia.npy')
GT_FILE_PAT = os.path.join(os.path.dirname(os.getcwd()), 'datasets/pavia/pavia_gt.npy')
experiment_dest_path = os.path.join(DEST_PATH, 'experiment_0')
os.makedirs(experiment_dest_path, exist_ok=True)

# %% [markdown]
# # Prepare the data
#
# To fit into the the pipeline, the data has to be preprocessed. It is achieved by the `prepare_data.main` function. It accepts a path to a `.npy` file with the original cube as well as the corresponding ground truth.  In this example, we randomly extract 250 samples from each class (balanced scenario), use 10% of them as validation set, and extract only spectral information of a pixel. The returned object is a dictiornary with three keys: `train`, `test` and `val`. Each of them contains an additional dictionary with `data` and `labels` keys, holding corresponding `numpy.ndarray` objects with the data. For more details about the parameters, refer to the documentation of `prepare_data.main` function (located in `scripts/prepare_data`).

# %%
data = prepare_data.main(data_file_path=DATA_FILE_PATH,
                            ground_truth_path=GT_FILE_PAT,
                            output_path=None,
                            train_size=250,
                            val_size=0.1,
                            stratified=True,
                            background_label=0,
                            channels_idx=2,
                            neighborhood_size=None,
                            save_data=False,
                            seed=0)

# %% [markdown]
# # Train the original model
#
# The function `trian_model.train` executed the trainig procedure. Trained model will be stored under `experiment_dest_path` folder path.

# %%
train_model.train(model_name='model_2d',
                    kernel_size=5,
                    n_kernels=200,
                    n_layers=1,
                    dest_path=experiment_dest_path,
                    data=data,
                    sample_size=103,
                    n_classes=9,
                    lr=0.001,
                    batch_size=128,
                    epochs=200,
                    verbose=2,
                    shuffle=True,
                    patience=15,
                    noise=[],
                    noise_sets=[])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 99, 1, 200)        1200
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 1, 200)        200200
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 1, 200)        200200
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 1, 200)         200200
# _________________________________________________________________
# flatten (Flatten)            (None, 1000)              0
# _________________________________________________________________
# dense (Dense)                (None, 200)               200200
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               25728
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 828,889
# Trainable params: 828,889
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2025 samples, validate on 225 samples
# Epoch 1/200
#  - 2s - loss: 1.8396 - acc: 0.2919 - val_loss: 1.2995 - val_acc: 0.5067
# Epoch 2/200
#  - 1s - loss: 1.0290 - acc: 0.5704 - val_loss: 0.9022 - val_acc: 0.6222
# Epoch 3/200
#  - 1s - loss: 0.7739 - acc: 0.6573 - val_loss: 0.7897 - val_acc: 0.6222
# Epoch 4/200
#  - 1s - loss: 0.6896 - acc: 0.6968 - val_loss: 0.6722 - val_acc: 0.7333
# Epoch 5/200
#  - 1s - loss: 0.6291 - acc: 0.7200 - val_loss: 0.5782 - val_acc: 0.7556
# Epoch 6/200
#  - 1s - loss: 0.5550 - acc: 0.7575 - val_loss: 0.6799 - val_acc: 0.6622
# Epoch 7/200
#  - 1s - loss: 0.6232 - acc: 0.7235 - val_loss: 0.6014 - val_acc: 0.7422
# Epoch 8/200
#  - 1s - loss: 0.5872 - acc: 0.7437 - val_loss: 0.5852 - val_acc: 0.7333
# Epoch 9/200
#  - 1s - loss: 0.5108 - acc: 0.7872 - val_loss: 0.5400 - val_acc: 0.7644
# Epoch 10/200
#  - 1s - loss: 0.5095 - acc: 0.7709 - val_loss: 0.6309 - val_acc: 0.6978
# Epoch 11/200
#  - 1s - loss: 0.5548 - acc: 0.7338 - val_loss: 0.5568 - val_acc: 0.7556
# Epoch 12/200
#  - 1s - loss: 0.4751 - acc: 0.7867 - val_loss: 0.5199 - val_acc: 0.7600
# Epoch 13/200
#  - 1s - loss: 0.4617 - acc: 0.8005 - val_loss: 0.4677 - val_acc: 0.7956
# Epoch 14/200
#  - 1s - loss: 0.4594 - acc: 0.8010 - val_loss: 0.4973 - val_acc: 0.7778
# Epoch 15/200
#  - 1s - loss: 0.4611 - acc: 0.7995 - val_loss: 0.5087 - val_acc: 0.7778
# Epoch 16/200
#  - 1s - loss: 0.4891 - acc: 0.7921 - val_loss: 0.5324 - val_acc: 0.7467
# Epoch 17/200
#  - 1s - loss: 0.4282 - acc: 0.8252 - val_loss: 0.4476 - val_acc: 0.8178
# Epoch 18/200
#  - 1s - loss: 0.4243 - acc: 0.8119 - val_loss: 0.5188 - val_acc: 0.7422
# Epoch 19/200
#  - 1s - loss: 0.4508 - acc: 0.8074 - val_loss: 0.4810 - val_acc: 0.7822
# Epoch 20/200
#  - 1s - loss: 0.4073 - acc: 0.8227 - val_loss: 0.4939 - val_acc: 0.7867
# Epoch 21/200
#  - 1s - loss: 0.3994 - acc: 0.8395 - val_loss: 0.4185 - val_acc: 0.8044
# Epoch 22/200
#  - 1s - loss: 0.3787 - acc: 0.8326 - val_loss: 0.5263 - val_acc: 0.7867
# Epoch 23/200
#  - 1s - loss: 0.4373 - acc: 0.8084 - val_loss: 0.4821 - val_acc: 0.8267
# Epoch 24/200
#  - 1s - loss: 0.3988 - acc: 0.8262 - val_loss: 0.4652 - val_acc: 0.8044
# Epoch 25/200
#  - 1s - loss: 0.3676 - acc: 0.8454 - val_loss: 0.4106 - val_acc: 0.8133
# Epoch 26/200
#  - 1s - loss: 0.3492 - acc: 0.8425 - val_loss: 0.4152 - val_acc: 0.8133
# Epoch 27/200
#  - 1s - loss: 0.3799 - acc: 0.8400 - val_loss: 0.4780 - val_acc: 0.8267
# Epoch 28/200
#  - 1s - loss: 0.3587 - acc: 0.8489 - val_loss: 0.3924 - val_acc: 0.8222
# Epoch 29/200
#  - 1s - loss: 0.3762 - acc: 0.8415 - val_loss: 0.4058 - val_acc: 0.8222
# Epoch 30/200
#  - 1s - loss: 0.3341 - acc: 0.8533 - val_loss: 0.4330 - val_acc: 0.8044
# Epoch 31/200
#  - 1s - loss: 0.3176 - acc: 0.8617 - val_loss: 0.4295 - val_acc: 0.8089
# Epoch 32/200
#  - 1s - loss: 0.3467 - acc: 0.8533 - val_loss: 0.4047 - val_acc: 0.8356
# Epoch 33/200
#  - 1s - loss: 0.3128 - acc: 0.8765 - val_loss: 0.3916 - val_acc: 0.8222
# Epoch 34/200
#  - 1s - loss: 0.3208 - acc: 0.8662 - val_loss: 0.4210 - val_acc: 0.8356
# Epoch 35/200
#  - 1s - loss: 0.3236 - acc: 0.8583 - val_loss: 0.3445 - val_acc: 0.8578
# Epoch 36/200
#  - 1s - loss: 0.3192 - acc: 0.8652 - val_loss: 0.3434 - val_acc: 0.8356
# Epoch 37/200
#  - 1s - loss: 0.2755 - acc: 0.8899 - val_loss: 0.3342 - val_acc: 0.8444
# Epoch 38/200
#  - 1s - loss: 0.2709 - acc: 0.8854 - val_loss: 0.3023 - val_acc: 0.8533
# Epoch 39/200
#  - 1s - loss: 0.2626 - acc: 0.8884 - val_loss: 0.3063 - val_acc: 0.8578
# Epoch 40/200
#  - 1s - loss: 0.2741 - acc: 0.8928 - val_loss: 0.3127 - val_acc: 0.8711
# Epoch 41/200
#  - 1s - loss: 0.2815 - acc: 0.8854 - val_loss: 0.2919 - val_acc: 0.8311
# Epoch 42/200
#  - 1s - loss: 0.2550 - acc: 0.8933 - val_loss: 0.3792 - val_acc: 0.8400
# Epoch 43/200
#  - 1s - loss: 0.2634 - acc: 0.8889 - val_loss: 0.4354 - val_acc: 0.8311
# Epoch 44/200
#  - 1s - loss: 0.3293 - acc: 0.8667 - val_loss: 0.3403 - val_acc: 0.8444
# Epoch 45/200
#  - 1s - loss: 0.2591 - acc: 0.8909 - val_loss: 0.4173 - val_acc: 0.8222
# Epoch 46/200
#  - 1s - loss: 0.3038 - acc: 0.8835 - val_loss: 0.3692 - val_acc: 0.8578
# Epoch 47/200
#  - 1s - loss: 0.2954 - acc: 0.8770 - val_loss: 0.3336 - val_acc: 0.8578
# Epoch 48/200
#  - 1s - loss: 0.2417 - acc: 0.9017 - val_loss: 0.3141 - val_acc: 0.8622
# Epoch 49/200
#  - 1s - loss: 0.2555 - acc: 0.8904 - val_loss: 0.3286 - val_acc: 0.8711
# Epoch 50/200
#  - 1s - loss: 0.2313 - acc: 0.9067 - val_loss: 0.3022 - val_acc: 0.8711
# Epoch 51/200
#  - 1s - loss: 0.2319 - acc: 0.8938 - val_loss: 0.2876 - val_acc: 0.8800
# Epoch 52/200
#  - 1s - loss: 0.2346 - acc: 0.9017 - val_loss: 0.2772 - val_acc: 0.8756
# Epoch 53/200
#  - 1s - loss: 0.2264 - acc: 0.9091 - val_loss: 0.3207 - val_acc: 0.8356
# Epoch 54/200
#  - 1s - loss: 0.2276 - acc: 0.9081 - val_loss: 0.3418 - val_acc: 0.8400
# Epoch 55/200
#  - 1s - loss: 0.2389 - acc: 0.9027 - val_loss: 0.2991 - val_acc: 0.8578
# Epoch 56/200
#  - 1s - loss: 0.2546 - acc: 0.8948 - val_loss: 0.3155 - val_acc: 0.8756
# Epoch 57/200
#  - 1s - loss: 0.2511 - acc: 0.8998 - val_loss: 0.3231 - val_acc: 0.8622
# Epoch 58/200
#  - 1s - loss: 0.2242 - acc: 0.9077 - val_loss: 0.3538 - val_acc: 0.8578
# Epoch 59/200
#  - 1s - loss: 0.2754 - acc: 0.8894 - val_loss: 0.4249 - val_acc: 0.8400
# Epoch 60/200
#  - 1s - loss: 0.2882 - acc: 0.8825 - val_loss: 0.2986 - val_acc: 0.8667
# Epoch 61/200
#  - 1s - loss: 0.2539 - acc: 0.8938 - val_loss: 0.2601 - val_acc: 0.8800
# Epoch 62/200
#  - 1s - loss: 0.2165 - acc: 0.9131 - val_loss: 0.2665 - val_acc: 0.9022
# Epoch 63/200
#  - 1s - loss: 0.2113 - acc: 0.9072 - val_loss: 0.2303 - val_acc: 0.8800
# Epoch 64/200
#  - 1s - loss: 0.2009 - acc: 0.9200 - val_loss: 0.2635 - val_acc: 0.8800
# Epoch 65/200
#  - 1s - loss: 0.1969 - acc: 0.9141 - val_loss: 0.2796 - val_acc: 0.8800
# Epoch 66/200
#  - 1s - loss: 0.2152 - acc: 0.9146 - val_loss: 0.3337 - val_acc: 0.8444
# Epoch 67/200
#  - 1s - loss: 0.2115 - acc: 0.9165 - val_loss: 0.2594 - val_acc: 0.8800
# Epoch 68/200
#  - 1s - loss: 0.1948 - acc: 0.9215 - val_loss: 0.2507 - val_acc: 0.8800
# Epoch 69/200
#  - 1s - loss: 0.2037 - acc: 0.9160 - val_loss: 0.2748 - val_acc: 0.8889
# Epoch 70/200
#  - 1s - loss: 0.1879 - acc: 0.9235 - val_loss: 0.2835 - val_acc: 0.8800
# Epoch 71/200
#  - 1s - loss: 0.2054 - acc: 0.9146 - val_loss: 0.3071 - val_acc: 0.8711
# Epoch 72/200
#  - 1s - loss: 0.2087 - acc: 0.9077 - val_loss: 0.2557 - val_acc: 0.8844
# Epoch 73/200
#  - 1s - loss: 0.2338 - acc: 0.9052 - val_loss: 0.2885 - val_acc: 0.8667
# Epoch 74/200
#  - 1s - loss: 0.2185 - acc: 0.9042 - val_loss: 0.2474 - val_acc: 0.8933
# Epoch 75/200
#  - 1s - loss: 0.1780 - acc: 0.9304 - val_loss: 0.2693 - val_acc: 0.8844
# Epoch 76/200
#  - 1s - loss: 0.1875 - acc: 0.9225 - val_loss: 0.2950 - val_acc: 0.8800
# Epoch 77/200
#  - 1s - loss: 0.2108 - acc: 0.9091 - val_loss: 0.2630 - val_acc: 0.9022
# Epoch 78/200
#  - 1s - loss: 0.2171 - acc: 0.9086 - val_loss: 0.2718 - val_acc: 0.8844

# %% [markdown]
# # Evaluate an ensemble of models
#
# To use an ensemble of augmented models, provide a `use_ensemble` argument. Indicate how many copies should be generated with `ensemble_copies` parameter. Lastly, indicate the voting algorithm. It accepts three values:
# - **hard**          - uses predicted class labels for majority rule voting.
# - **soft**          - predicts the class label based on the argmax of the sums of the predicted probabilities.
# - **classifier**    - Use a classifier which accepts predicted probabilities from all the models as features and return the final prediction. The                            classifier is trained on the train set predictions. Random forest will be used.
#
# Each layer is modified separately. It is achieved by drawing a random number for each of the parameters of the layer. The number is drawn from the normal distribution with provided mean and standard deviation calculated from the layer's parameters, multiplied by `0.1`.

# %%
evaluate_model.evaluate(
    model_path=os.path.join(experiment_dest_path, 'model_2d'),
    data=data,
    dest_path=experiment_dest_path,
    n_classes=9,
    batch_size=1024,
    use_ensemble=True,
    ensemble_copies=4,
    voting='hard',
    noise=[],
    noise_sets=[],
    noise_params="{\"mean\": 0, \"std\": None}")
tf.keras.backend.clear_session()
# Out:
# /home/michal/anaconda3/envs/decent/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py:542: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   append_fn(tensor_proto, proto_values)
